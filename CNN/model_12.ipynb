# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import to_categorical

from keras.models import Sequential,load_model

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
np.random.seed(1)

# %%
train_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        './images2/train',
        target_size = (300,300),
        batch_size=50,
        #color_mode ='rgb',
        classes = ['food','interior', 'exterior'],
        shuffle =True,
        seed = 42,
        class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        './images2/test',
        classes = ['food','interior', 'exterior'],
        target_size=(300,300),
        batch_size=10,
#         color_mode ='rgb',
        shuffle =True,
        seed = 42,
        class_mode='categorical')
# Out:
# Found 36000 images belonging to 3 classes.
# Found 9000 images belonging to 3 classes.

# %%
iterations = 200

train_plus = train_datagen.flow_from_directory(
    './images2/train',
    target_size = (300,300),
    batch_size = 50,
    class_mode = 'categorical')

#for i in enumerate(range(iterations)):
#    img, label = train_plus.next()
    
    
test_plus = test_datagen.flow_from_directory(
    './images2/test',
    target_size = (300,300),
    batch_size = 10,
    class_mode = 'categorical')

#for i in enumerate(range(iterations)):
#    img, label = train_plus.next()
# Out:
# Found 36000 images belonging to 3 classes.
# Found 9000 images belonging to 3 classes.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=3,
                 activation='selu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(16, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
# model.add(Dense(8, activation='selu'))
# model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=10,
    epochs=10,
    validation_data=test_generator,
    validation_steps=5)

model.save('model-12')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 147, 147, 16)      4624
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 73, 73, 16)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 85264)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 255795
# =================================================================
# Total params: 261,315
# Trainable params: 261,315
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 15s 2s/step - loss: 3.4377 - accuracy: 0.3940 - val_loss: 1.0528 - val_accuracy: 0.6200
# Epoch 2/10
# 10/10 [==============================] - 17s 2s/step - loss: 1.3245 - accuracy: 0.5480 - val_loss: 1.9570 - val_accuracy: 0.4800
# Epoch 3/10
# 10/10 [==============================] - 17s 2s/step - loss: 1.1297 - accuracy: 0.6120 - val_loss: 1.0427 - val_accuracy: 0.5200
# Epoch 4/10
# 10/10 [==============================] - 18s 2s/step - loss: 0.8999 - accuracy: 0.6220 - val_loss: 0.8318 - val_accuracy: 0.6400
# Epoch 5/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.8765 - accuracy: 0.5820 - val_loss: 0.8755 - val_accuracy: 0.5600
# Epoch 6/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.7781 - accuracy: 0.6400 - val_loss: 0.7266 - val_accuracy: 0.6800
# Epoch 7/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.8034 - accuracy: 0.6560 - val_loss: 0.7956 - val_accuracy: 0.7200
# Epoch 8/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.7263 - accuracy: 0.7080 - val_loss: 0.8161 - val_accuracy: 0.6000
# Epoch 9/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.7712 - accuracy: 0.6740 - val_loss: 0.6865 - val_accuracy: 0.7400
# Epoch 10/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.7409 - accuracy: 0.6780 - val_loss: 0.8568 - val_accuracy: 0.6400
# INFO:tensorflow:Assets written to: model-12\assets
# -- Evaluate --
# accuracy: 76.00%
# -- Predict --
# {'food': 0, 'interior': 1, 'exterior': 2}
# [[0.208 0.675 0.117]
#  [0.954 0.006 0.040]
#  [0.388 0.338 0.274]
#  [0.439 0.393 0.168]
#  [0.764 0.194 0.043]
#  [0.037 0.481 0.482]
#  [0.807 0.120 0.073]
#  [0.956 0.043 0.001]
#  [0.041 0.066 0.893]
#  [0.117 0.861 0.022]
#  [0.915 0.016 0.068]
#  [0.714 0.170 0.115]
#  [0.892 0.070 0.038]
#  [0.438 0.071 0.491]
#  [0.243 0.709 0.048]
#  [0.060 0.286 0.654]
#  [0.030 0.059 0.911]
#  [0.529 0.277 0.194]
#  [0.034 0.893 0.073]
#  [0.414 0.253 0.333]
#  [0.193 0.288 0.519]
#  [0.847 0.086 0.067]
#  [0.034 0.189 0.777]
#  [0.502 0.242 0.256]
#  [0.309 0.654 0.037]
#  [0.235 0.428 0.337]
#  [0.738 0.228 0.034]
#  [0.191 0.477 0.333]
#  [0.994 0.005 0.001]
#  [0.125 0.648 0.226]
#  [0.078 0.147 0.775]
#  [0.158 0.230 0.612]
#  [0.142 0.408 0.450]
#  [0.185 0.415 0.400]
#  [0.931 0.041 0.028]
#  [0.239 0.760 0.001]
#  [0.902 0.007 0.091]
#  [0.028 0.115 0.857]
#  [0.746 0.206 0.048]
#  [0.021 0.133 0.846]
#  [0.147 0.704 0.149]
#  [0.010 0.342 0.648]
#  [0.226 0.653 0.121]
#  [0.134 0.530 0.336]
#  [0.943 0.038 0.019]
#  [0.612 0.298 0.090]
#  [0.664 0.054 0.282]
#  [0.296 0.437 0.267]
#  [0.266 0.581 0.153]
#  [0.116 0.836 0.048]]

# %%
print(train_generator.class_indices)
print(test_generator.class_indices)
# Out:
# {'food': 0, 'interior': 1, 'exterior': 2}
# {'food': 0, 'interior': 1, 'exterior': 2}
