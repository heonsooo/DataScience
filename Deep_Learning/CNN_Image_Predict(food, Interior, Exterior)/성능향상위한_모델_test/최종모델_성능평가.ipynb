# %%
#에러 코드 핸들링

import os

import warnings

 

import numpy as np

import tensorflow as tf

import matplotlib.pyplot as plt
 

#디렉토리 -> numpy 변환

import cv2



# 이미지 -> 디렉토리 및 라벨링

from keras.preprocessing.image import ImageDataGenerator

from keras.utils import to_categorical

 

#모델링

from keras.models import Sequential,load_model
from tensorflow.keras.layers import  Input, Conv2D, MaxPooling2D, Dense, Flatten, experimental, Dropout

# from tensorflow.keras.callbacks import ModelCheckpoint

import pandas as pd 


import datetime
 

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

warnings.filterwarnings(action='ignore')

# %%
# 데이터 증폭

train_data_augmentation = ImageDataGenerator(

    validation_split = 0.2,

    rotation_range=10,

    zoom_range = 0.3,

    width_shift_range=0.2,

    height_shift_range=0.2)

#train 데이터 설정 

train_data = train_data_augmentation.flow_from_directory(

        './images2/train',

        target_size = (300,300),

        batch_size=150,

        #color_mode ='rgb',

        classes = ['food','interior', 'exterior'],

        shuffle =True,

        class_mode='categorical')


# validation 데이터 설정

validation_data = train_data_augmentation.flow_from_directory(

        './images2/train',

        target_size = (300,300),

        batch_size=100,

        classes = ['food','interior', 'exterior'],

        shuffle =True,

        class_mode='categorical',

        subset='validation')

 
#test 데이터 설정

test_data = ImageDataGenerator().flow_from_directory(

        './images2/test',

        classes = ['food','interior', 'exterior'],

        target_size=(300,300),

        batch_size=25,

        class_mode='categorical')
# Out:
# Found 38752 images belonging to 3 classes.
# Found 7749 images belonging to 3 classes.
# Found 6248 images belonging to 3 classes.

# %% [markdown]
# # Model - 201814132

# %%
model = Sequential([

Input(shape=(300,300,3), name='input_layer'),

experimental.preprocessing.Rescaling(1./255),

Conv2D(32,(3,3), activation='relu',name='Conv_layer1'),

MaxPooling2D(pool_size=(2,2),name='Pooling_layer2'),
    

Conv2D(96,(3,3), activation='relu',name='Conv_layer3'),

MaxPooling2D(pool_size=(2,2),name='Pooling_layer4'),

 

Conv2D(64,(3,3), activation='relu',name='Conv_layer5'),

MaxPooling2D(pool_size=(2,2),name='Pooling_layer6'),
    

Dropout(0.5),

Conv2D(128,(3,3), activation='relu',name='Conv_layer7'),

MaxPooling2D(pool_size=(2,2),name='Pooling_layer8'),

Flatten(),

Dense(160, activation='relu',name='FC_layer9', kernel_initializer='glorot_uniform',),

Dense(20, activation='relu',name='FC_layer10', kernel_initializer='glorot_uniform',),

Dense(3, activation='softmax', name='output_layer11')

])

 

 

# 3. 모델 학습과정 설정 및 요약

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])






a = datetime.datetime.now()
print('fitting start', a)

# 4. 모델 학습
def model_():
    history = model.fit(

        train_data,

        steps_per_epoch=15,

        epochs=30,

        validation_data=validation_data,

        validation_steps=10)


    return history


model.save('model-201814132')
b = datetime.datetime.now()
history = model_()
print('Fitting End', b)
print('Fitting Time =' , b-a)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 300, 300, 3)       0
# _________________________________________________________________
# Conv_layer1 (Conv2D)         (None, 298, 298, 32)      896
# _________________________________________________________________
# Pooling_layer2 (MaxPooling2D (None, 149, 149, 32)      0
# _________________________________________________________________
# Conv_layer3 (Conv2D)         (None, 147, 147, 96)      27744
# _________________________________________________________________
# Pooling_layer4 (MaxPooling2D (None, 73, 73, 96)        0
# _________________________________________________________________
# Conv_layer5 (Conv2D)         (None, 71, 71, 64)        55360
# _________________________________________________________________
# Pooling_layer6 (MaxPooling2D (None, 35, 35, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 35, 35, 64)        0
# _________________________________________________________________
# Conv_layer7 (Conv2D)         (None, 33, 33, 128)       73856
# _________________________________________________________________
# Pooling_layer8 (MaxPooling2D (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC_layer9 (Dense)            (None, 160)               5243040
# _________________________________________________________________
# FC_layer10 (Dense)           (None, 20)                3220
# _________________________________________________________________
# output_layer11 (Dense)       (None, 3)                 63
# =================================================================
# Total params: 5,404,179
# Trainable params: 5,404,179
# Non-trainable params: 0
# _________________________________________________________________
# fitting start 2020-12-17 18:05:21.480089
# INFO:tensorflow:Assets written to: Model_Go_X7\assets
# Epoch 1/30
# 15/15 [==============================] - 208s 14s/step - loss: 1.4857 - accuracy: 0.3731 - val_loss: 1.0880 - val_accuracy: 0.4590
# Epoch 2/30
# 15/15 [==============================] - 210s 14s/step - loss: 1.0617 - accuracy: 0.4522 - val_loss: 0.9925 - val_accuracy: 0.4710
# Epoch 3/30
# 15/15 [==============================] - 210s 14s/step - loss: 0.9456 - accuracy: 0.5220 - val_loss: 0.9840 - val_accuracy: 0.5800
# Epoch 4/30
# 15/15 [==============================] - 211s 14s/step - loss: 0.9129 - accuracy: 0.5513 - val_loss: 0.8860 - val_accuracy: 0.5880
# Epoch 5/30
# 15/15 [==============================] - 211s 14s/step - loss: 0.8280 - accuracy: 0.5994 - val_loss: 0.8837 - val_accuracy: 0.5890
# Epoch 6/30
# 15/15 [==============================] - 199s 13s/step - loss: 0.8355 - accuracy: 0.6079 - val_loss: 0.8991 - val_accuracy: 0.5940
# Epoch 7/30
# 15/15 [==============================] - 197s 13s/step - loss: 0.8007 - accuracy: 0.6466 - val_loss: 0.8596 - val_accuracy: 0.6230
# Epoch 8/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.8018 - accuracy: 0.6384 - val_loss: 0.8581 - val_accuracy: 0.5990
# Epoch 9/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.8651 - accuracy: 0.6019 - val_loss: 0.8469 - val_accuracy: 0.6370
# Epoch 10/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.7937 - accuracy: 0.6313 - val_loss: 0.8793 - val_accuracy: 0.6540
# Epoch 11/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.8119 - accuracy: 0.6359 - val_loss: 0.8240 - val_accuracy: 0.6580
# Epoch 12/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.7868 - accuracy: 0.6436 - val_loss: 0.8169 - val_accuracy: 0.6580
# Epoch 13/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.7930 - accuracy: 0.6413 - val_loss: 0.8497 - val_accuracy: 0.6040
# Epoch 14/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.7913 - accuracy: 0.6350 - val_loss: 0.7884 - val_accuracy: 0.6650
# Epoch 15/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.7574 - accuracy: 0.6648 - val_loss: 0.7901 - val_accuracy: 0.6950
# Epoch 16/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.7109 - accuracy: 0.6805 - val_loss: 0.7786 - val_accuracy: 0.6680
# Epoch 17/30
# 15/15 [==============================] - 203s 14s/step - loss: 0.6506 - accuracy: 0.7253 - val_loss: 0.7060 - val_accuracy: 0.7350
# Epoch 18/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.6587 - accuracy: 0.7274 - val_loss: 0.7457 - val_accuracy: 0.7180
# Epoch 19/30
# 15/15 [==============================] - 203s 14s/step - loss: 0.6552 - accuracy: 0.7301 - val_loss: 0.6345 - val_accuracy: 0.7420
# Epoch 20/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5852 - accuracy: 0.7496 - val_loss: 0.6541 - val_accuracy: 0.7460
# Epoch 21/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.6579 - accuracy: 0.7165 - val_loss: 0.6733 - val_accuracy: 0.7400
# Epoch 22/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5817 - accuracy: 0.7575 - val_loss: 0.6782 - val_accuracy: 0.7250
# Epoch 23/30
# 15/15 [==============================] - 203s 14s/step - loss: 0.6229 - accuracy: 0.7420 - val_loss: 0.6287 - val_accuracy: 0.7510
# Epoch 24/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5863 - accuracy: 0.7510 - val_loss: 0.5345 - val_accuracy: 0.8090
# Epoch 25/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5609 - accuracy: 0.7835 - val_loss: 0.7154 - val_accuracy: 0.7390
# Epoch 26/30
# 15/15 [==============================] - 203s 13s/step - loss: 0.5737 - accuracy: 0.7642 - val_loss: 0.5875 - val_accuracy: 0.7870
# Epoch 27/30
# 15/15 [==============================] - 203s 14s/step - loss: 0.6267 - accuracy: 0.7385 - val_loss: 0.6090 - val_accuracy: 0.7770
# Epoch 28/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5411 - accuracy: 0.7777 - val_loss: 0.5565 - val_accuracy: 0.8080
# Epoch 29/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5110 - accuracy: 0.8039 - val_loss: 0.5542 - val_accuracy: 0.7730
# Epoch 30/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5012 - accuracy: 0.7929 - val_loss: 0.5535 - val_accuracy: 0.8020
# INFO:tensorflow:Assets written to: Model_Go_X7\assets
# Fitting End 2020-12-17 18:05:23.346966
# Fitting Time = 0:00:01.866877

# %%
model.save('model-201814132')
# Out:
# INFO:tensorflow:Assets written to: Model_Go_XX7\assets

# %%
history = model_()
def plot_loss_curve(history):

    plt.figure(figsize = (5,3))

    plt.plot(history['loss'])

    plt.plot(history['val_loss'])


    plt.title('model loss')

    plt.xlabel('epoch')

    plt.ylabel('loss')

    plt.legend(['train','test'], loc = 'upper right')

    plt.show

    
def plot_accuracy_curve(history):

    plt.figure(figsize = (5,3))

    plt.plot(history['accuracy'])

    plt.plot(history['val_accuracy'])


    plt.title('model accuracy')

    plt.xlabel('epoch')

    plt.ylabel('accuracy')

    plt.legend(['train','test'], loc = 'upper right')

    plt.show
# Out:
# Epoch 1/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.5060 - accuracy: 0.7973 - val_loss: 0.5974 - val_accuracy: 0.7510
# Epoch 2/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5588 - accuracy: 0.7684 - val_loss: 0.5824 - val_accuracy: 0.7830
# Epoch 3/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5115 - accuracy: 0.7982 - val_loss: 0.5896 - val_accuracy: 0.7760
# Epoch 4/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5252 - accuracy: 0.7938 - val_loss: 0.6183 - val_accuracy: 0.7340
# Epoch 5/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5308 - accuracy: 0.7751 - val_loss: 0.5818 - val_accuracy: 0.7800
# Epoch 6/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.5282 - accuracy: 0.7916 - val_loss: 0.5564 - val_accuracy: 0.8140
# Epoch 7/30
# 15/15 [==============================] - 206s 14s/step - loss: 0.5023 - accuracy: 0.8076 - val_loss: 0.5071 - val_accuracy: 0.8070
# Epoch 8/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4871 - accuracy: 0.7969 - val_loss: 0.5369 - val_accuracy: 0.8050
# Epoch 9/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5223 - accuracy: 0.7849 - val_loss: 0.5304 - val_accuracy: 0.8050
# Epoch 10/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4549 - accuracy: 0.8258 - val_loss: 0.5076 - val_accuracy: 0.8130
# Epoch 11/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4789 - accuracy: 0.8089 - val_loss: 0.5638 - val_accuracy: 0.7750
# Epoch 12/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4940 - accuracy: 0.8044 - val_loss: 0.5671 - val_accuracy: 0.7780
# Epoch 13/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4868 - accuracy: 0.8129 - val_loss: 0.5459 - val_accuracy: 0.8180
# Epoch 14/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4736 - accuracy: 0.8076 - val_loss: 0.5711 - val_accuracy: 0.7580
# Epoch 15/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4799 - accuracy: 0.8053 - val_loss: 0.4791 - val_accuracy: 0.8110
# Epoch 16/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5214 - accuracy: 0.7867 - val_loss: 0.5403 - val_accuracy: 0.8160
# Epoch 17/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4625 - accuracy: 0.8093 - val_loss: 0.5043 - val_accuracy: 0.8100
# Epoch 18/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4627 - accuracy: 0.8169 - val_loss: 0.5220 - val_accuracy: 0.7960
# Epoch 19/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4841 - accuracy: 0.8151 - val_loss: 0.5721 - val_accuracy: 0.8040
# Epoch 20/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4730 - accuracy: 0.8196 - val_loss: 0.5124 - val_accuracy: 0.8040
# Epoch 21/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4649 - accuracy: 0.8173 - val_loss: 0.4893 - val_accuracy: 0.8330
# Epoch 22/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4652 - accuracy: 0.8204 - val_loss: 0.4888 - val_accuracy: 0.8200
# Epoch 23/30
# 15/15 [==============================] - 204s 14s/step - loss: 0.4477 - accuracy: 0.8253 - val_loss: 0.5095 - val_accuracy: 0.8150
# Epoch 24/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4652 - accuracy: 0.8187 - val_loss: 0.4987 - val_accuracy: 0.8300
# Epoch 25/30
# 15/15 [==============================] - 206s 14s/step - loss: 0.4729 - accuracy: 0.8120 - val_loss: 0.5213 - val_accuracy: 0.8000
# Epoch 26/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4292 - accuracy: 0.8360 - val_loss: 0.4536 - val_accuracy: 0.8140
# Epoch 27/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4688 - accuracy: 0.8182 - val_loss: 0.5016 - val_accuracy: 0.8310
# Epoch 28/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.3982 - accuracy: 0.8502 - val_loss: 0.4637 - val_accuracy: 0.8280
# Epoch 29/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4674 - accuracy: 0.8133 - val_loss: 0.5216 - val_accuracy: 0.8320
# Epoch 30/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.4548 - accuracy: 0.8267 - val_loss: 0.4943 - val_accuracy: 0.8260
# INFO:tensorflow:Assets written to: Model_Go_X7\assets

# %%
plot_accuracy_curve(history.history)

print('train accuracy ={} , validation accuracy ={}' .format(
                                                            round(history.history['accuracy'][-1],5), 
                                                            round(history.history['val_accuracy'][-1],5) ))
plot_loss_curve(history.history)
print('train loss ={} ,     validation loss ={}' .format(
                                                        round(history.history['loss'][-1],5), 
                                                        round(history.history['val_loss'][-1],5) ))
# Out:
# train accuracy =0.82667 , validation accuracy =0.826
# train loss =0.45478 ,     validation loss =0.49428
