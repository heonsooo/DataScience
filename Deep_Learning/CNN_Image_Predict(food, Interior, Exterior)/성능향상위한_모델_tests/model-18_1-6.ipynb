# %% [markdown]
# Full connected 뉴런 적게 2개 Layer

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import to_categorical

from keras.models import Sequential,load_model

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
np.random.seed(1)


train_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    validation_split = 0.2,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        './images2/train',
        target_size = (300,300),
        batch_size=50,
        classes = ['food','interior', 'exterior'],
        shuffle =True,
        seed = 42,
        class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        './images2/test',
        classes = ['food','interior', 'exterior'],
        target_size=(300,300),
        batch_size=10,
        shuffle =True,
        seed = 42,
        class_mode='categorical')
# Out:
# Found 36000 images belonging to 3 classes.
# Found 9000 images belonging to 3 classes.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Conv2D(32, 3, activation='selu'))
# model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))




# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=10,
    epochs=10,
    validation_data=test_generator,
    validation_steps=20)

model.save('model-18')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 149, 149, 32)      0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 710432)            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 5683464
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,684,459
# Trainable params: 5,684,459
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 14s 1s/step - loss: 8.3984 - accuracy: 0.3860 - val_loss: 4.1200 - val_accuracy: 0.2250
# Epoch 2/10
# 10/10 [==============================] - 15s 1s/step - loss: 2.8679 - accuracy: 0.3520 - val_loss: 1.8773 - val_accuracy: 0.5050
# Epoch 3/10
# 10/10 [==============================] - 15s 1s/step - loss: 1.1990 - accuracy: 0.5320 - val_loss: 1.0151 - val_accuracy: 0.4950
# Epoch 4/10
# 10/10 [==============================] - 15s 2s/step - loss: 0.9799 - accuracy: 0.4940 - val_loss: 0.8403 - val_accuracy: 0.6000
# Epoch 5/10
# 10/10 [==============================] - 15s 2s/step - loss: 0.8978 - accuracy: 0.5680 - val_loss: 0.8292 - val_accuracy: 0.6300
# Epoch 6/10
# 10/10 [==============================] - 16s 2s/step - loss: 0.8782 - accuracy: 0.5800 - val_loss: 0.7891 - val_accuracy: 0.6750
# Epoch 7/10
# 10/10 [==============================] - 16s 2s/step - loss: 0.8994 - accuracy: 0.5880 - val_loss: 0.8917 - val_accuracy: 0.6450
# Epoch 8/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.8447 - accuracy: 0.6220 - val_loss: 0.8273 - val_accuracy: 0.6500
# Epoch 9/10
# 10/10 [==============================] - 16s 2s/step - loss: 0.8538 - accuracy: 0.5920 - val_loss: 0.8063 - val_accuracy: 0.7000
# Epoch 10/10
# 10/10 [==============================] - 16s 2s/step - loss: 0.8602 - accuracy: 0.6420 - val_loss: 0.8817 - val_accuracy: 0.5700
# INFO:tensorflow:Assets written to: model-18\assets
# -- Evaluate --
# accuracy: 72.00%
# -- Predict --
# {'food': 0, 'interior': 1, 'exterior': 2}
# [[0.849 0.143 0.008]
#  [0.925 0.073 0.002]
#  [0.606 0.324 0.071]
#  [0.185 0.474 0.341]
#  [0.309 0.487 0.205]
#  [0.773 0.220 0.007]
#  [0.048 0.197 0.755]
#  [0.962 0.036 0.002]
#  [0.168 0.695 0.138]
#  [0.163 0.592 0.245]
#  [0.531 0.380 0.088]
#  [0.279 0.556 0.165]
#  [0.995 0.005 0.000]
#  [0.308 0.590 0.102]
#  [0.064 0.321 0.615]
#  [0.262 0.344 0.394]
#  [0.798 0.180 0.022]
#  [0.811 0.179 0.010]
#  [0.107 0.398 0.496]
#  [0.500 0.422 0.078]
#  [0.645 0.328 0.026]
#  [0.054 0.317 0.628]
#  [0.616 0.306 0.078]
#  [0.044 0.062 0.894]
#  [0.471 0.449 0.080]
#  [0.214 0.654 0.132]
#  [0.031 0.256 0.713]
#  [0.286 0.575 0.139]
#  [0.319 0.527 0.153]
#  [0.173 0.387 0.439]
#  [0.422 0.357 0.221]
#  [0.681 0.228 0.091]
#  [0.874 0.123 0.003]
#  [0.534 0.428 0.038]
#  [0.812 0.151 0.037]
#  [0.189 0.694 0.118]
#  [0.338 0.391 0.272]
#  [0.176 0.633 0.190]
#  [0.986 0.012 0.002]
#  [0.693 0.301 0.007]
#  [0.139 0.303 0.558]
#  [0.308 0.668 0.024]
#  [0.206 0.588 0.206]
#  [0.336 0.391 0.273]
#  [0.815 0.156 0.029]
#  [0.089 0.465 0.446]
#  [0.011 0.143 0.846]
#  [0.084 0.502 0.414]
#  [0.219 0.537 0.245]
#  [0.991 0.009 0.001]]

# %% [markdown]
# epohc 10 -> 30 수정
#   -> 너무 많은 시간..

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Conv2D(32, 3, activation='selu'))
# model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=10,
    epochs=30,
    validation_data=test_generator,
    validation_steps=30)

model.save('model-18-4')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=10)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=10)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 149, 149, 32)      0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 710432)            0
# _________________________________________________________________
# dense_27 (Dense)             (None, 8)                 5683464
# _________________________________________________________________
# dense_28 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_29 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,684,459
# Trainable params: 5,684,459
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 10/10 [==============================] - 42s 4s/step - loss: 2.8354 - accuracy: 0.3340 - val_loss: 1.0993 - val_accuracy: 0.3500
# Epoch 2/30
# 10/10 [==============================] - 39s 4s/step - loss: 1.0996 - accuracy: 0.3220 - val_loss: 1.0985 - val_accuracy: 0.3633
# Epoch 3/30
# 10/10 [==============================] - 42s 4s/step - loss: 1.0971 - accuracy: 0.3140 - val_loss: 1.0964 - val_accuracy: 0.3333
# Epoch 4/30
# 10/10 [==============================] - 41s 4s/step - loss: 1.1016 - accuracy: 0.3160 - val_loss: 1.0932 - val_accuracy: 0.2967
# Epoch 5/30
# 10/10 [==============================] - 38s 4s/step - loss: 1.0940 - accuracy: 0.3920 - val_loss: 1.0941 - val_accuracy: 0.4500
# Epoch 6/30
# 10/10 [==============================] - 41s 4s/step - loss: 1.0952 - accuracy: 0.4320 - val_loss: 1.0934 - val_accuracy: 0.4367
# Epoch 7/30
# 10/10 [==============================] - 44s 4s/step - loss: 1.0936 - accuracy: 0.4380 - val_loss: 1.0921 - val_accuracy: 0.4300
# Epoch 8/30
# 10/10 [==============================] - 40s 4s/step - loss: 1.0914 - accuracy: 0.4440 - val_loss: 1.0927 - val_accuracy: 0.4400
# Epoch 9/30
# 10/10 [==============================] - 38s 4s/step - loss: 1.0901 - accuracy: 0.4540 - val_loss: 1.0902 - val_accuracy: 0.4600
# Epoch 10/30
#  5/10 [==============>...............] - ETA: 14s - loss: 1.0926 - accuracy: 0.4240
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8191b03c4045> in <module>
#      21     epochs=30,
#      22     validation_data=test_generator,
# ---> 23     validation_steps=30)
#      24
#      25 model.save('model-18-4')
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1827         use_multiprocessing=use_multiprocessing,
#    1828         shuffle=shuffle,
# -> 1829         initial_epoch=initial_epoch)
#    1830
#    1831   @deprecation.deprecated(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Conv층 32개 -> 64개

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(3,3),
                 activation='relu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Conv2D(32, 3, activation='selu'))
# model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=10,
    epochs=10,
    validation_data=test_generator,
    validation_steps=20)

model.save('model-18-2')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)

# %% [markdown]
# Conv, pooling  추가

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(3,3),
                 activation='relu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=10,
    epochs=10,
    validation_data=test_generator,
    validation_steps=20)

model.save('model-18-2-2')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)

# %% [markdown]
# epoch 조절
# 활성함수 relu -> selu

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=30,
    epochs=10,
    validation_data=test_generator,
    validation_steps=30)

model.save('model-18-3')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=10)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=10)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 149, 149, 32)      0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 710432)            0
# _________________________________________________________________
# dense_18 (Dense)             (None, 8)                 5683464
# _________________________________________________________________
# dense_19 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,684,459
# Trainable params: 5,684,459
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 30/30 [==============================] - 95s 3s/step - loss: 4.6164 - accuracy: 0.4027 - val_loss: 1.2005 - val_accuracy: 0.3400
# Epoch 2/10
# 30/30 [==============================] - 105s 4s/step - loss: 1.0255 - accuracy: 0.4347 - val_loss: 0.9682 - val_accuracy: 0.4667
# Epoch 3/10
# 30/30 [==============================] - 105s 4s/step - loss: 0.9722 - accuracy: 0.4727 - val_loss: 0.9235 - val_accuracy: 0.4933
# Epoch 4/10
# 30/30 [==============================] - 109s 4s/step - loss: 0.9485 - accuracy: 0.4913 - val_loss: 0.9332 - val_accuracy: 0.6000
# Epoch 5/10
# 30/30 [==============================] - 116s 4s/step - loss: 0.9411 - accuracy: 0.5320 - val_loss: 1.0055 - val_accuracy: 0.5400
# Epoch 6/10
# 30/30 [==============================] - 105s 3s/step - loss: 0.9682 - accuracy: 0.5367 - val_loss: 0.9276 - val_accuracy: 0.5167
# Epoch 7/10
# 30/30 [==============================] - 116s 4s/step - loss: 0.9074 - accuracy: 0.5493 - val_loss: 0.8442 - val_accuracy: 0.5900
# Epoch 8/10
# 30/30 [==============================] - 113s 4s/step - loss: 0.8995 - accuracy: 0.5500 - val_loss: 0.8609 - val_accuracy: 0.5733
# Epoch 9/10
# 30/30 [==============================] - 108s 4s/step - loss: 0.9000 - accuracy: 0.5807 - val_loss: 0.8606 - val_accuracy: 0.6300
# Epoch 10/10
# 30/30 [==============================] - 107s 4s/step - loss: 0.8710 - accuracy: 0.5853 - val_loss: 0.8725 - val_accuracy: 0.6000
# INFO:tensorflow:Assets written to: model-18-3\assets
# -- Evaluate --
# accuracy: 63.00%
# -- Predict --
# {'food': 0, 'interior': 1, 'exterior': 2}
# [[0.500 0.247 0.253]
#  [0.263 0.456 0.281]
#  [0.275 0.385 0.340]
#  [0.302 0.334 0.364]
#  [0.268 0.397 0.334]
#  [0.302 0.334 0.364]
#  [0.238 0.545 0.218]
#  [0.463 0.301 0.237]
#  [0.712 0.180 0.108]
#  [0.364 0.400 0.236]
#  [0.261 0.459 0.280]
#  [0.873 0.115 0.013]
#  [0.302 0.334 0.364]
#  [0.936 0.060 0.004]
#  [0.840 0.108 0.052]
#  [0.842 0.151 0.007]
#  [0.553 0.342 0.105]
#  [0.709 0.146 0.145]
#  [0.366 0.377 0.257]
#  [0.371 0.428 0.201]
#  [0.711 0.178 0.111]
#  [0.397 0.347 0.256]
#  [0.241 0.496 0.263]
#  [0.506 0.265 0.230]
#  [0.839 0.145 0.016]
#  [0.334 0.332 0.334]
#  [0.376 0.310 0.314]
#  [0.302 0.334 0.364]
#  [0.278 0.444 0.279]
#  [0.857 0.141 0.001]
#  [0.310 0.346 0.344]
#  [0.544 0.214 0.242]
#  [0.322 0.400 0.278]
#  [0.726 0.179 0.095]
#  [0.279 0.464 0.257]
#  [0.884 0.088 0.028]
#  [0.944 0.054 0.001]
#  [0.582 0.192 0.226]
#  [0.452 0.470 0.078]
#  [0.302 0.334 0.364]
#  [0.984 0.013 0.003]
#  [0.300 0.337 0.363]
#  [0.707 0.201 0.092]
#  [0.848 0.117 0.035]
#  [0.965 0.034 0.002]
#  [0.758 0.209 0.033]
#  [0.301 0.382 0.316]
#  [0.479 0.333 0.188]
#  [0.360 0.304 0.336]
#  [0.488 0.239 0.273]
#  [0.630 0.200 0.170]
#  [0.937 0.059 0.004]
#  [0.743 0.167 0.090]
#  [0.294 0.360 0.346]
#  [0.305 0.391 0.304]
#  [0.974 0.024 0.001]
#  [0.401 0.286 0.313]
#  [0.801 0.189 0.010]
#  [0.916 0.055 0.029]
#  [0.483 0.319 0.198]
#  [0.813 0.117 0.070]
#  [0.285 0.365 0.350]
#  [0.283 0.464 0.253]
#  [0.902 0.074 0.024]
#  [0.970 0.024 0.007]
#  [0.613 0.177 0.210]
#  [0.422 0.501 0.077]
#  [0.285 0.376 0.339]
#  [0.526 0.220 0.254]
#  [0.304 0.336 0.360]
#  [0.939 0.048 0.013]
#  [0.389 0.314 0.297]
#  [0.592 0.259 0.149]
#  [0.583 0.374 0.043]
#  [0.843 0.131 0.026]
#  [0.255 0.484 0.262]
#  [0.953 0.036 0.010]
#  [0.471 0.356 0.173]
#  [0.413 0.439 0.148]
#  [0.335 0.317 0.348]
#  [0.916 0.077 0.007]
#  [0.885 0.081 0.034]
#  [0.855 0.119 0.025]
#  [0.268 0.478 0.254]
#  [0.234 0.470 0.296]
#  [0.264 0.472 0.264]
#  [0.818 0.128 0.055]
#  [0.931 0.052 0.018]
#  [0.282 0.465 0.253]
#  [0.309 0.401 0.290]
#  [0.618 0.283 0.100]
#  [0.295 0.400 0.305]
#  [0.489 0.261 0.250]
#  [0.972 0.022 0.006]
#  [0.379 0.459 0.162]
#  [0.708 0.172 0.120]
#  [0.233 0.620 0.147]
#  [0.299 0.340 0.362]
#  [0.666 0.270 0.064]
#  [0.616 0.314 0.070]]

# %% [markdown]
# Conv, Pooling 추가

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=(300,300,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(32, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(32, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(32, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(32, 3, activation='selu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 3. 모델 학습과정 설정 및 요약
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
    train_generator,
    steps_per_epoch=30,
    epochs=10,
    validation_data=test_generator,
    validation_steps=30)

model.save('model-18-3')

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=10)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=10)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 147, 147, 32)      9248
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 71, 71, 32)        9248
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 33, 33, 32)        9248
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 5, 5, 32)          9248
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 8)                 1032
# _________________________________________________________________
# dense_22 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 48,267
# Trainable params: 48,267
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 30/30 [==============================] - 128s 4s/step - loss: 1.0786 - accuracy: 0.4240 - val_loss: 0.9830 - val_accuracy: 0.5167
# Epoch 2/10
# 30/30 [==============================] - 137s 5s/step - loss: 0.9668 - accuracy: 0.5313 - val_loss: 0.9183 - val_accuracy: 0.5600
# Epoch 3/10
# 30/30 [==============================] - 135s 5s/step - loss: 0.9335 - accuracy: 0.5480 - val_loss: 0.8877 - val_accuracy: 0.6267
# Epoch 4/10
# 30/30 [==============================] - 134s 4s/step - loss: 0.8504 - accuracy: 0.6047 - val_loss: 0.8054 - val_accuracy: 0.6267
# Epoch 5/10
# 30/30 [==============================] - 134s 4s/step - loss: 0.9096 - accuracy: 0.5573 - val_loss: 0.9032 - val_accuracy: 0.5333
# Epoch 6/10
# 30/30 [==============================] - 78s 3s/step - loss: 0.8873 - accuracy: 0.5800 - val_loss: 0.8472 - val_accuracy: 0.6233
# Epoch 7/10
# 30/30 [==============================] - 75s 2s/step - loss: 0.8574 - accuracy: 0.6073 - val_loss: 0.7862 - val_accuracy: 0.6667
# Epoch 8/10
# 30/30 [==============================] - 74s 2s/step - loss: 0.8666 - accuracy: 0.6073 - val_loss: 0.8434 - val_accuracy: 0.5733
# Epoch 9/10
# 30/30 [==============================] - 81s 3s/step - loss: 0.8248 - accuracy: 0.6247 - val_loss: 0.7345 - val_accuracy: 0.6800
# Epoch 10/10
# 30/30 [==============================] - 79s 3s/step - loss: 0.8486 - accuracy: 0.6000 - val_loss: 0.8274 - val_accuracy: 0.6667
# INFO:tensorflow:Assets written to: model-18-3\assets
# -- Evaluate --
# accuracy: 54.00%
# -- Predict --
# {'food': 0, 'interior': 1, 'exterior': 2}
# [[0.892 0.066 0.042]
#  [0.602 0.297 0.101]
#  [0.168 0.372 0.460]
#  [0.263 0.588 0.150]
#  [0.130 0.418 0.452]
#  [0.763 0.137 0.100]
#  [0.296 0.472 0.232]
#  [0.201 0.631 0.168]
#  [0.425 0.275 0.299]
#  [0.615 0.351 0.034]
#  [0.701 0.239 0.060]
#  [0.304 0.599 0.097]
#  [0.259 0.665 0.077]
#  [0.733 0.227 0.041]
#  [0.210 0.572 0.217]
#  [0.850 0.093 0.057]
#  [0.119 0.585 0.296]
#  [0.468 0.264 0.268]
#  [0.227 0.450 0.323]
#  [0.819 0.113 0.069]
#  [0.434 0.222 0.344]
#  [0.604 0.294 0.102]
#  [0.190 0.376 0.434]
#  [0.739 0.140 0.120]
#  [0.173 0.484 0.342]
#  [0.556 0.195 0.249]
#  [0.217 0.397 0.387]
#  [0.716 0.224 0.060]
#  [0.918 0.029 0.054]
#  [0.129 0.456 0.414]
#  [0.891 0.094 0.015]
#  [0.628 0.176 0.196]
#  [0.372 0.436 0.192]
#  [0.107 0.509 0.385]
#  [0.538 0.403 0.059]
#  [0.407 0.478 0.115]
#  [0.349 0.434 0.217]
#  [0.950 0.032 0.018]
#  [0.360 0.499 0.140]
#  [0.195 0.404 0.401]
#  [0.132 0.350 0.518]
#  [0.054 0.600 0.346]
#  [0.175 0.482 0.343]
#  [0.168 0.628 0.203]
#  [0.415 0.489 0.096]
#  [0.915 0.077 0.008]
#  [0.979 0.016 0.005]
#  [0.092 0.362 0.546]
#  [0.167 0.409 0.424]
#  [0.510 0.220 0.270]
#  [0.426 0.504 0.071]
#  [0.450 0.269 0.281]
#  [0.838 0.150 0.012]
#  [0.197 0.540 0.263]
#  [0.152 0.561 0.287]
#  [0.650 0.280 0.070]
#  [0.098 0.779 0.122]
#  [0.465 0.452 0.083]
#  [0.128 0.396 0.476]
#  [0.790 0.155 0.054]
#  [0.142 0.354 0.504]
#  [0.140 0.424 0.436]
#  [0.881 0.057 0.062]
#  [0.558 0.197 0.245]
#  [0.128 0.557 0.315]
#  [0.360 0.321 0.318]
#  [0.622 0.228 0.149]
#  [0.678 0.233 0.089]
#  [0.140 0.330 0.530]
#  [0.353 0.564 0.083]
#  [0.774 0.082 0.144]
#  [0.951 0.041 0.008]
#  [0.179 0.398 0.424]
#  [0.359 0.314 0.327]
#  [0.141 0.497 0.362]
#  [0.835 0.065 0.100]
#  [0.762 0.212 0.025]
#  [0.922 0.058 0.020]
#  [0.896 0.051 0.053]
#  [0.867 0.104 0.029]
#  [0.840 0.132 0.027]
#  [0.796 0.131 0.073]
#  [0.243 0.371 0.386]
#  [0.339 0.469 0.192]
#  [0.185 0.444 0.371]
#  [0.842 0.101 0.058]
#  [0.774 0.172 0.054]
#  [0.197 0.443 0.359]
#  [0.268 0.697 0.034]
#  [0.056 0.527 0.417]
#  [0.128 0.719 0.154]
#  [0.231 0.716 0.053]
#  [0.277 0.479 0.244]
#  [0.197 0.369 0.434]
#  [0.732 0.170 0.098]
#  [0.895 0.090 0.015]
#  [0.368 0.483 0.150]
#  [0.842 0.137 0.021]
#  [0.245 0.634 0.120]
#  [0.169 0.428 0.404]]
