# %% [markdown]
# # Final CNN
#
# ## 모듈 정의

# %%
#에러 코드 핸들링
import os
import warnings

import datetime
import numpy as np
import matplotlib.pyplot as plt

# 이미지 -> 디렉토리 및 라벨링
from keras.preprocessing.image import ImageDataGenerator
#from keras.utils import to_categorical

#모델링
from keras.models import Sequential,load_model
from tensorflow.keras.layers import  Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 이미지데이터
# 1) 이미지 데이터를 Keras 의 ImageDataGenerator함수 이용해서
#    Keras내의 directory에 저장합니다.
#
# 2) 이때 train 데이터는 증폭하여 저장했습니다.
#
# 3) 그리고 실제 train 데이터를 저장하였고
# 4) validation 데이터와 4:1 비율로 나누었습니다.
# 5) 이때 subset으로  Train data, Validation data로 표기도 했습니다.
# 6) 그리고 test 데이터도 같은 방법으로 사용했습니다.
#
# ---
# [참고]
# - 시행착오 : 데이터사이언스개론_딥러닝_이미지분류
#   -> 이미지데이터 -> numpy로 하나하나 다 불러와서
#      data split도 직접 하고
#      음식, 실내, 실외 데이터 합치다가
#      메모리 초과..

# %%
# 데이터 증폭
'''
validation_split = 0.2,  => train : validation 8:2 
rotation_range=10,      =>회전 각도 10도까지
zoom_range = 0.3,       => 확대 범위
width_shift_range=0.2,  => 좌우 이동 범위
height_shift_range=0.2) => 상하 이동 범위
'''
train_data_augmentation = ImageDataGenerator(
    validation_split = 0.2,
    rotation_range=10,
    zoom_range = 0.3,
    width_shift_range=0.2,
    height_shift_range=0.2)

#train 데이터 설정 
train_data = train_data_augmentation.flow_from_directory(
        './images2/train',
        target_size = (300,300),
        batch_size=150,
        classes = ['food','interior', 'exterior'],
        shuffle =True,
        class_mode='categorical')


# validation 데이터 설정
validation_data = train_data_augmentation.flow_from_directory(
        './images2/train',
        target_size = (300,300),
        batch_size=400,
        classes = ['food','interior', 'exterior'],
        shuffle =True,
        class_mode='categorical',
        subset='validation')

#test 데이터 설정
test_data = ImageDataGenerator().flow_from_directory(
        './images2/test',
        classes = ['food','interior', 'exterior'],
        target_size=(300,300),
        batch_size=100,
        shuffle =True,
        class_mode='categorical')
# Out:
# Found 36000 images belonging to 3 classes.
# Found 7200 images belonging to 3 classes.
# Found 9000 images belonging to 3 classes.

# %% [markdown]
# # Model Layers
#
# - 가장 어려운 문제였습니다.

# %%
model = Sequential([

Input(shape=(300,300,3), name='input_layer'),
experimental.preprocessing.Rescaling(1./255),
    
Conv2D(32,(3,3), activation='relu',name='Conv_layer1'),
MaxPooling2D(pool_size=(2,2),name='Pooling_layer2'),   

Conv2D(96,(3,3), activation='relu',name='Conv_layer3'),
MaxPooling2D(pool_size=(2,2),name='Pooling_layer4'),

Conv2D(64,(3,3), activation='relu',name='Conv_layer5'),
MaxPooling2D(pool_size=(2,2),name='Pooling_layer6'), 

Dropout(0.5),
Conv2D(128,(3,3), activation='relu',name='Conv_layer7'),
MaxPooling2D(pool_size=(2,2),name='Pooling_layer8'),

Flatten(),
Dense(160, activation='relu',name='FC_layer9', kernel_initializer='glorot_uniform',),
Dense(20, activation='relu',name='FC_layer10', kernel_initializer='glorot_uniform',),
Dense(3, activation='softmax', name='output_layer11')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8b929160a8b2> in <module>
#       2
#       3 Input(shape=(300,300,3), name='input_layer'),
# ----> 4 experimental.preprocessing.Rescaling(1./255),
#       5
#       6 Conv2D(32,(3,3), activation='relu',name='Conv_layer1'),
#
# NameError: name 'experimental' is not defined

# %% [markdown]
# # 3. 모델 학습과정 설정 및 요약

# %%
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 300, 300, 3)       0
# _________________________________________________________________
# Conv_layer1 (Conv2D)         (None, 298, 298, 32)      896
# _________________________________________________________________
# Pooling_layer2 (MaxPooling2D (None, 149, 149, 32)      0
# _________________________________________________________________
# Conv_layer3 (Conv2D)         (None, 147, 147, 96)      27744
# _________________________________________________________________
# Pooling_layer4 (MaxPooling2D (None, 73, 73, 96)        0
# _________________________________________________________________
# Conv_layer5 (Conv2D)         (None, 71, 71, 64)        55360
# _________________________________________________________________
# Pooling_layer6 (MaxPooling2D (None, 35, 35, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 35, 35, 64)        0
# _________________________________________________________________
# Conv_layer7 (Conv2D)         (None, 33, 33, 128)       73856
# _________________________________________________________________
# Pooling_layer8 (MaxPooling2D (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# FC_layer9 (Dense)            (None, 160)               5243040
# _________________________________________________________________
# FC_layer10 (Dense)           (None, 20)                3220
# _________________________________________________________________
# output_layer11 (Dense)       (None, 3)                 63
# =================================================================
# Total params: 5,404,179
# Trainable params: 5,404,179
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Fitting

# %%
a = datetime.datetime.now()
print('fitting start', a)

# 4. 모델 학습
def model_():
    history = model.fit(

        train_data,

        steps_per_epoch=15,

        epochs=30,

        validation_data=validation_data,

        validation_steps=10)

    model.save('model-201814132')
    return history


model.save('model-201814132')
b = datetime.datetime.now()
history = model_()
print('Fitting End', b)
print('Fitting Time =' , b-a)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 300, 300, 3)       0
# _________________________________________________________________
# Conv_layer1 (Conv2D)         (None, 298, 298, 32)      896
# _________________________________________________________________
# Pooling_layer2 (MaxPooling2D (None, 149, 149, 32)      0
# _________________________________________________________________
# Conv_layer3 (Conv2D)         (None, 147, 147, 96)      27744
# _________________________________________________________________
# Pooling_layer4 (MaxPooling2D (None, 73, 73, 96)        0
# _________________________________________________________________
# Conv_layer5 (Conv2D)         (None, 71, 71, 64)        55360
# _________________________________________________________________
# Pooling_layer6 (MaxPooling2D (None, 35, 35, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 35, 35, 64)        0
# _________________________________________________________________
# Conv_layer7 (Conv2D)         (None, 33, 33, 128)       73856
# _________________________________________________________________
# Pooling_layer8 (MaxPooling2D (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# FC_layer9 (Dense)            (None, 160)               5243040
# _________________________________________________________________
# FC_layer10 (Dense)           (None, 20)                3220
# _________________________________________________________________
# output_layer11 (Dense)       (None, 3)                 63
# =================================================================
# Total params: 5,404,179
# Trainable params: 5,404,179
# Non-trainable params: 0
# _________________________________________________________________
# fitting start 2020-12-17 15:35:14.644874
# INFO:tensorflow:Assets written to: Model_Go_X6\assets
# Epoch 1/30
# 15/15 [==============================] - 212s 14s/step - loss: 1.2986 - accuracy: 0.3968 - val_loss: 1.0545 - val_accuracy: 0.4590
# Epoch 2/30
# 15/15 [==============================] - 207s 14s/step - loss: 0
30
# 15/15 [==============================] - 206s 14s/step - loss: 0.5239 - accuracy: 0.7806 - val_loss: 0.8739 - val_accuracy: 0.6400
# Epoch 30/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.4992 - accuracy: 0.8022 - val_loss: 0.7415 - val_accuracy: 0.6680
# Fitting End 2020-12-17 15:35:16.379262
# Fitting Time = 0:00:01.734388

# %%
a = datetime.datetime.now()
print('fitting start',a)

def model_():
    history = model.fit(
                        train_data,
                        steps_per_epoch = 10,
                        epochs= 15,
                        validation_data=validation_data,
                        validation_steps=10)
    
    model.save('model-201814132')
    return history

b = datetime.datetime.now()
print('Fitting End',b)
print('Fitting Time = ' , b-a)

# %% [markdown]
# ## 그래프 함수
# 1) loss 그래프 함수
# 2) accuracy 그래프 함수

# %%
def plot_loss_curve(history):
    plt.figure(figsize = (5,3))
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    
    plt.legend(['train','test'], loc = 'upper right')
    plt.show

    
def plot_accuracy_curve(history):
    plt.figure(figsize = (5,3))
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])

    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    
    plt.legend(['train','test'], loc = 'upper right')
    plt.show

# %%
plot_accuracy_curve(history.history)

print('train accuracy ={} , validation accuracy ={}' .format(
                                                            round(history.history['accuracy'][-1],5), 
                                                            round(history.history['val_accuracy'][-1],5) ))
plot_loss_curve(history.history)
print('train loss ={} ,     validation loss ={}' .format(
                                                        round(history.history['loss'][-1],5), 
                                                        round(history.history['val_loss'][-1],5) ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-0567b0f5cb96> in <module>
# ----> 1 plot_accuracy_curve(history.history)
#       2
#       3 print('train accuracy ={} , validation accuracy ={}' .format(
#       4                                                             round(history.history['accuracy'][-1],5),
#       5                                                             round(history.history['val_accuracy'][-1],5) ))
#
# NameError: name 'history' is not defined

# %% [markdown]
# # 모델 평가

# %%
print("-- Evaluate --")

scores = model.evaluate_generator(test_data, steps=5)

print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

 

# 6. 모델 사용하기

print("-- Predict --")

output = model.predict_generator(test_data, steps=5)

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

print(test_data.class_indices)

print(output)
# Out:
# -- Evaluate --
# accuracy: 43.20%
# -- Predict --
# {'food': 0, 'interior': 1, 'exterior': 2}
# [[0.440 0.306 0.254]
#  [0.500 0.291 0.209]
#  [0.339 0.328 0.332]
#  [0.362 0.330 0.309]
#  [0.331 0.334 0.335]
#  [0.394 0.320 0.285]
#  [0.531 0.280 0.189]
#  [0.455 0.299 0.246]
#  [0.690 0.211 0.099]
#  [0.500 0.294 0.205]
#  [0.502 0.291 0.207]
#  [0.451 0.307 0.242]
#  [0.506 0.290 0.204]
#  [0.362 0.331 0.306]
#  [0.333 0.332 0.335]
#  [0.380 0.321 0.300]
#  [0.339 0.332 0.329]
#  [0.513 0.289 0.198]
#  [0.340 0.330 0.330]
#  [0.437 0.306 0.257]
#  [0.334 0.334 0.332]
#  [0.361 0.329 0.311]
#  [0.431 0.310 0.259]
#  [0.359 0.328 0.313]
#  [0.412 0.317 0.271]
#  [0.373 0.321 0.305]
#  [0.342 0.330 0.327]
#  [0.333 0.331 0.335]
#  [0.359 0.331 0.310]
#  [0.356 0.328 0.316]]

# %%
## 그래프


def plot_loss_curve(history):

    plt.figure(figsize = (5,3))

    plt.plot(history['loss'])

    plt.plot(history['val_loss'])


    plt.title('model loss')

    plt.xlabel('epoch')

    plt.ylabel('loss')

    plt.legend(['train','test'], loc = 'upper right')

    plt.show

    
def plot_accuracy_curve(history):

    plt.figure(figsize = (5,3))

    plt.plot(history['accuracy'])

    plt.plot(history['val_accuracy'])


    plt.title('model accuracy')

    plt.xlabel('epoch')

    plt.ylabel('accuracy')

    plt.legend(['train','test'], loc = 'upper right')

    plt.show

plot_accuracy_curve(history.history)

print('train accuracy ={} , validation accuracy ={}' .format(
                                                            round(history.history['accuracy'][-1],5), 
                                                            round(history.history['val_accuracy'][-1],5) ))
plot_loss_curve(history.history)
print('train loss ={} ,     validation loss ={}' .format(
                                                        round(history.history['loss'][-1],5), 
                                                        round(history.history['val_loss'][-1],5) ))

model = load_model('Model_Go_X4')
# 5. 모델 평가하기

print("-- Evaluate --")

scores = model.evaluate_generator(test_data, steps=5)

print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

 

# 6. 모델 사용하기

print("-- Predict --")

output = model.predict_generator(test_data, steps=5)

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

print(test_data.class_indices)

print(output)

# %%
def plot_loss_curve(history):
    plt.figure(figsize = (5,3))
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['train','test'], loc = 'upper right')
    plt.show

# %% [markdown]
# # test image(data) numpy array
# 1) 데이터 처리에 가장 문제가 많았습니다.
# 2) 왜냐하면 numpy array로 변환하기위해서 많은 노력을했습니다.
#    한번에 많이 올리면 메모리 초과로 고배를 마시고
#    나눠서 올려서 합치려고 했었는데 이마저도 결국 메모리 부족으로 불가했습니다.
# 3) 그렇게 이미지제네레이터를 알게되었고
#    이는 폴더내에서 이미지를 나누어놓고 클래스를 지정해놓으면 그대로 라벨링하며 딕셔너리로 만들어 주는 함수를 찾았습니다.
# 4) 그 폴더를 가지고 훈련은 시켰으나
#    (훈련에도 굉장히 많은 시간이.. ㅠㅠ)
# 5) 출력에 와서 굉장히 큰 문제가 발생했습니다.
# 6) 바로... 어떻게 꺼내와야하는지도 몰랐고, 라벨링이 어떻게 되어있는지도 몰랐습니다.
# 7) 그렇게
#    x=np.concatenate([test_data.next()[0] for i in range(test_data.__len__())])
#    y=np.concatenate([test_data.next()[1] for i in range(test_data.__len__())])
#    numpy의 concatenate를 적용했지만
#    예측함수를 통해 예측하는중에 라벨링이 이상한걸보고
#    하나하나 사진을 출력해보며 이미지 데이터와 확인해보니 라벨링이 엉망으로 되어있었씁니다.
#    이는 넘파이에서 행과 열에서 하나씩 붙여오다보니 오류가 난거라고 생각하였고
#    큰 고민에 빠졌습니다.
#
#  8) 그렇게 next 함수를 발견하였고 너무나 쉽게 딕셔너리가 numpy array로 변해 들어감을 확인했고
#     실제값에 정확하게 라벨링이되어있는걸 확인할 수 있었씁니다.

# %%
X,y = test_data.next()

# %% [markdown]
# # 클래스 출력
#
# ### 클래스 출력을 숫자로 하니 자꾸 헷갈려서 한글로 출력하도록 함수 만들었습니다.

# %%
def print_class(Num):
    class_of_Image = '음식' if Num == 0 else '실내' if Num==1 else '실외'
    return class_of_Image

# %% [markdown]
# # 예측 함수
#    1) NoPrint : 각 예측값들 확인 안하고 총 정확도만 보기 위해
#    2) Print 모든 과정 예측값 확인

# %%
def predict_image_sample_Noprint(model,X_test, y_test,test_id= -1 ):

    if test_id <0 :
        from random import randrange
        test_sample_id = randrange(len(y))
    else:
        test_sample_id = test_id
        
    test_image =X_test[test_sample_id]

    test_image = test_image.reshape(1,300,300,3)
    

    y_actual = y_test[test_sample_id]

    y_actual_num = np.argmax(y_actual)
    actual_class = print_class(y_actual_num)


    y_pred = model.predict(test_image)
    
    y_pred_num = np.argmax(y_pred, axis = 1)[0]
    predict_class = print_class(y_pred_num)

    if y_pred_num != y_actual_num:
        with open("wrong_samples.txt", "a") as errfile:
            print('%d'%test_sample_id, file = errfile)
    else:
        pass
    
    return y_actual_num, y_pred_num
#model = load_model('Model_Go_X3')
#predict_image_sample_Noprint(model,X, y)

# %%
def predict_image_sample_Print(model,X_test, y_test,test_id= -1 ):

    if test_id <0 :
        from random import randrange
        test_sample_id = randrange(len(y))

    else:
        test_sample_id = test_id

    test_image =X_test[test_sample_id]


    #이미지로 만들기
    pixels = np.array(test_image,np.int32)
    plt.imshow(pixels)
    
    test_image = test_image.reshape(1,300,300,3)
    
   
    y_actual = y_test[test_sample_id]
    #print( y_actual)
    y_actual_num = np.argmax(y_actual)
    actual_class = print_class(y_actual_num)
    
    
    y_pred = model.predict(test_image)
    
   
    y_pred_num = np.argmax(y_pred, axis = 1)[0]
    predict_class = print_class(y_pred_num)

    #print('실제 클래스 = ', actual_class)
    #print('예측 클래스 = ', predict_class)
    
    
    print('Actual= {}({}) , Predict= {}({})'.format(actual_class,y_actual_num ,predict_class,y_pred_num))
    print("\ny_pred = ", y_pred)
    print('-'*15)
    
    if y_pred_num != y_actual_num:
        with open("틀린 이미지들.txt", "a") as errfile:
            print("%d"%test_sample_id, file=errfile)
    else:
        pass

    
    return y_actual_num, y_pred_num

'''
print(test_data.class_indices,'\n')
model = load_model(' ')
predict_image_sample_Print(model,X, y)
'''
# Out:
# "\nprint(test_data.class_indices,'\n')\nmodel = load_model(' ')\npredict_image_sample_Print(model,X, y)\n"

# %% [markdown]
# # Model 통해 예측
#
# 1) test_data를 경로를 input하여 지정해주세요.
# 2) load_model을 통해 지정한 모델을 불러옵니다.
# 3)

# %%
#test 데이터 설정
#path = '  ./images2/test  '
path = input()
test_data = ImageDataGenerator().flow_from_directory(
        path,
        classes = ['food','interior', 'exterior'],
        target_size=(300,300),
        batch_size=400,
        shuffle =True,
        class_mode='categorical')


if __name__ == '__main__' :
    X_test , y_test = test_data.next()
    model = load_model('model-201814132')
    
    corr,count = 0,0
    y_true_mat, y_pred_mat = [] , []
    
    for i in range(len(y)):
        count +=1
        y_act, y_pre = predict_image_sample_Print(model,X_test, y_test)
        y_true_mat.append(y_act)
        y_pred_mat.append(y_pre) 
        if y_act == y_pre :
            corr +=1 
        else:
            continue
    
    print('총횟수 = {} , 맞춘횟수={} , 정확도(Accuracy)={} '.format(count,corr, (corr/count)*100 ) )
# Out:
# ./images2/test
# Found 9000 images belonging to 3 classes.
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.
]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.0350511 0.5552301 0.4097188]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.9523346  0.04130495 0.00636046]]
# ---------------
# Actual= 실내(1) , Predict= 음식(0)
#
# y_pred =  [[0.57274354 0.28688672 0.14036977]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.00189556 0.9108198  0.08728456]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.22989215 0.44228792 0.32781994]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.00802015 0.5170683  0.4749115 ]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.0066415  0.5885363  0.40482214]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.0786192  0.82575816 0.09562264]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.8424591  0.14436617 0.01317466]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.5209191  0.3899315  0.08914945]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.0018898  0.40289953 0.59521073]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.01080329 0.43161514 0.55758154]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.00498078 0.4153175  0.57970166]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.04723583 0.33973423 0.61302996]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.01341234 0.7811534  0.20543426]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.7094615  0.23742314 0.05311535]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.6767627  0.2669582  0.05627909]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.24705033 0.39591667 0.35703295]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.01053645 0.76321393 0.22624958]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.7790777  0.18750277 0.03341955]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.04859233 0.45737222 0.49403536]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.01400372 0.06307182 0.92292446]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.01389757 0.3729906  0.6131118 ]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.8006299  0.16682565 0.03254434]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.04983442 0.4817599  0.46840563]]
# ---------------
# Actual= 음식(0) , Predict= 실외(2)
#
# y_pred =  [[0.02596088 0.3127452  0.6612939 ]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.0248168  0.9016658  0.07351746]]
# ---------------
# Actual= 음식(0) , Predict= 실외(2)
#
# y_pred =  [[0.02130635 0.41275135 0.56594235]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.8968051  0.08469319 0.01850172]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.00928626 0.22247766 0.7682361 ]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.71030134 0.22329989 0.06639872]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.00616529 0.10913333 0.8847013 ]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.0125065  0.7170944  0.27039906]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.00720901 0.15196647 0.84082454]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.7514497  0.19197786 0.05657239]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.17263766 0.6180674  0.20929489]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.00412501 0.72737426 0.26850066]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.02350849 0.2747854  0.7017062 ]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.52587897 0.2937675  0.18035349]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.15342379 0.77299076 0.07358541]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.672631   0.2609213  0.06644765]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.6888467  0.20405167 0.10710155]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.00442956 0.9710173  0.02455311]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.00809297 0.8001164  0.1917905 ]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.01236659 0.23465036 0.7529831 ]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.1407272  0.62401414 0.23525868]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.00928626 0.22247766 0.7682361 ]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.01365    0.8257273  0.16062269]]
# ---------------
# Actual= 음식(0) , Predict= 음식(0)
#
# y_pred =  [[0.85669297 0.11399546 0.02931165]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.03034658 0.22398472 0.74566877]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.27816206 0.5729921  0.14884584]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.00929869 0.832241   0.15846023]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.02761945 0.8247028  0.14767776]]
# ---------------
# Actual= 실외(2) , Predict= 실외(2)
#
# y_pred =  [[0.02528653 0.2747708  0.6999427 ]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.17263766 0.6180674  0.20929489]]
# ---------------
# Actual= 실내(1) , Predict= 실내(1)
#
# y_pred =  [[0.02442032 0.8225851  0.15299453]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.29552016 0.5069642  0.19751564]]
# ---------------
# Actual= 실내(1) , Predict= 실외(2)
#
# y_pred =  [[0.04859233 0.45737222 0.49403536]]
# ---------------
# Actual= 음식(0) , Predict= 실외(2)
#
# y_pred =  [[0.05314759 0.43804973 0.50880265]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.23145074 0.66596544 0.1025838 ]]
# ---------------
# Actual= 음식(0) , Predict= 실내(1)
#
# y_pred =  [[0.25063214 0.44657287 0.30279496]]
# ---------------
# 총횟수 = 400 , 맞춘횟수=279 , 정확도(Accuracy)=69.75

# %% [markdown]
# ### Precision ,Recall,F1-score

# %%
from sklearn.metrics import precision_recall_fscore_support as score
import pandas as pd
precision, recall, fscore, support = score(y_true_mat, y_pred_mat)

Confusion_Matrix = pd.DataFrame(np.array([precision, recall, fscore]),
                               columns = ['음식','실내','실외'] ,
                               index  = ["Precision", "Recall", "F1-score"])
print(Confusion_Matrix)
# Out:
#                  음식        실내        실외
# Precision  0.892857  0.533333  0.444444
# Recall     0.510204  0.727273  0.666667
# F1-score   0.649351  0.615385  0.533333

# %% [markdown]
# # 이미지 검증

# %%
a = datetime.datetime.now()
print('fitting start', a)

# 4. 모델 학습
def model_():
    history = model.fit(

        train_data,

        steps_per_epoch=15,

        epochs=30,

        validation_data=validation_data,

        validation_steps=10)

    model.save('model-201814132')
    return history


model.save('model-201814132')
b = datetime.datetime.now()
#history = model_()
print('Fitting End', b)
print('Fitting Time =' , b-a)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 300, 300, 3)       0
# _________________________________________________________________
# Conv_layer1 (Conv2D)         (None, 298, 298, 32)      896
# _________________________________________________________________
# Pooling_layer2 (MaxPooling2D (None, 149, 149, 32)      0
# _________________________________________________________________
# Conv_layer3 (Conv2D)         (None, 147, 147, 96)      27744
# _________________________________________________________________
# Pooling_layer4 (MaxPooling2D (None, 73, 73, 96)        0
# _________________________________________________________________
# Conv_layer5 (Conv2D)         (None, 71, 71, 64)        55360
# _________________________________________________________________
# Pooling_layer6 (MaxPooling2D (None, 35, 35, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 35, 35, 64)        0
# _________________________________________________________________
# Conv_layer7 (Conv2D)         (None, 33, 33, 128)       73856
# _________________________________________________________________
# Pooling_layer8 (MaxPooling2D (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# FC_layer9 (Dense)            (None, 160)               5243040
# _________________________________________________________________
# FC_layer10 (Dense)           (None, 20)                3220
# _________________________________________________________________
# output_layer11 (Dense)       (None, 3)                 63
# =================================================================
# Total params: 5,404,179
# Trainable params: 5,404,179
# Non-trainable params: 0
# _________________________________________________________________
# fitting start 2020-12-17 15:35:14.644874
# INFO:tensorflow:Assets written to: Model_Go_X6\assets
# Epoch 1/30
# 15/15 [==============================] - 212s 14s/step - loss: 1.2986 - accuracy: 0.3968 - val_loss: 1.0545 - val_accuracy: 0.4590
# Epoch 2/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.9748 - accuracy: 0.4444 - val_loss: 1.0073 - val_accuracy: 0.4700
# Epoch 3/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.9761 - accuracy: 0.4692 - val_loss: 0.9583 - val_accuracy: 0.5320
# Epoch 4/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.9236 - accuracy: 0.5296 - val_loss: 0.9214 - val_accuracy: 0.5630
# Epoch 5/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.9004 - accuracy: 0.5544 - val_loss: 0.9847 - val_accuracy: 0.5250
# Epoch 6/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.8833 - accuracy: 0.5795 - val_loss: 0.8701 - val_accuracy: 0.5950
# Epoch 7/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.8343 - accuracy: 0.6115 - val_loss: 0.9347 - val_accuracy: 0.5380
# Epoch 8/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.8211 - accuracy: 0.6296 - val_loss: 0.8335 - val_accuracy: 0.6310
# Epoch 9/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.7883 - accuracy: 0.6403 - val_loss: 0.8936 - val_accuracy: 0.5980
# Epoch 10/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.7867 - accuracy: 0.6530 - val_loss: 0.8831 - val_accuracy: 0.6210
# Epoch 11/30
# 15/15 [==============================] - 198s 13s/step - loss: 0.7904 - accuracy: 0.6481 - val_loss: 0.8535 - val_accuracy: 0.6170
# Epoch 12/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.7166 - accuracy: 0.6952 - val_loss: 0.7839 - val_accuracy: 0.6850
# Epoch 13/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.7435 - accuracy: 0.6917 - val_loss: 0.8257 - val_accuracy: 0.6360
# Epoch 14/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.6704 - accuracy: 0.6979 - val_loss: 0.9107 - val_accuracy: 0.6050
# Epoch 15/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.6907 - accuracy: 0.6969 - val_loss: 0.7516 - val_accuracy: 0.6870
# Epoch 16/30
# 15/15 [==============================] - 206s 14s/step - loss: 0.6665 - accuracy: 0.7274 - val_loss: 0.6135 - val_accuracy: 0.7780
# Epoch 17/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.6092 - accuracy: 0.7334 - val_loss: 0.6647 - val_accuracy: 0.7460
# Epoch 18/30
# 15/15 [==============================] - 197s 14s/step - loss: 0.5680 - accuracy: 0.7699 - val_loss: 0.5798 - val_accuracy: 0.7840
# Epoch 19/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.6661 - accuracy: 0.7053 - val_loss: 0.6204 - val_accuracy: 0.7880
# Epoch 20/30
# 15/15 [==============================] - 206s 14s/step - loss: 0.6112 - accuracy: 0.7351 - val_loss: 0.7848 - val_accuracy: 0.6450
# Epoch 21/30
# 15/15 [==============================] - 206s 14s/step - loss: 0.5415 - accuracy: 0.7818 - val_loss: 0.6348 - val_accuracy: 0.7360
# Epoch 22/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5466 - accuracy: 0.7750 - val_loss: 0.6379 - val_accuracy: 0.7410
# Epoch 23/30
# 15/15 [==============================] - 205s 14s/step - loss: 0.5301 - accuracy: 0.7771 - val_loss: 0.6677 - val_accuracy: 0.6950
# Epoch 24/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.5212 - accuracy: 0.7906 - val_loss: 0.5961 - val_accuracy: 0.7690
# Epoch 25/30
# 15/15 [==============================] - 210s 14s/step - loss: 0.5328 - accuracy: 0.7848 - val_loss: 0.6485 - val_accuracy: 0.7090
# Epoch 26/30
# 15/15 [==============================] - 209s 14s/step - loss: 0.5550 - accuracy: 0.7726 - val_loss: 0.6245 - val_accuracy: 0.7500
# Epoch 27/30
# 15/15 [==============================] - 210s 14s/step - loss: 0.4971 - accuracy: 0.8020 - val_loss: 0.6190 - val_accuracy: 0.7360
# Epoch 28/30
# 15/15 [==============================] - 214s 14s/step - loss: 0.5016 - accuracy: 0.7927 - val_loss: 0.6825 - val_accuracy: 0.7280
# Epoch 29/30
# 15/15 [==============================] - 206s 14s/step - loss: 0.5239 - accuracy: 0.7806 - val_loss: 0.8739 - val_accuracy: 0.6400
# Epoch 30/30
# 15/15 [==============================] - 207s 14s/step - loss: 0.4992 - accuracy: 0.8022 - val_loss: 0.7415 - val_accuracy: 0.6680
# Fitting End 2020-12-17 15:35:16.379262
# Fitting Time = 0:00:01.734388

# %%
image_num = int(input())
test_image =X_test[image_num]

pixels = np.array(test_image,np.int32)
plt.imshow(pixels)

test_image = test_image.reshape(1,300,300,3)


y_actual = y_test[image_num]

y_actual_num = np.argmax(y_actual)
actual_class = print_class(y_actual_num)


y_pred = model.predict(test_image)


y_pred_num = np.argmax(y_pred, axis = 1)[0]
predict_class = print_class(y_pred_num)


    
print('Actual= {}({}) , Predict= {}({})'.format(actual_class,y_actual_num ,predict_class,y_pred_num))
print("\ny_pred = ", y_pred)
# Out:
# 394
# Actual= 음식(0) , Predict= 실외(2)
#
# y_pred =  [[0.05314759 0.43804973 0.50880265]]
